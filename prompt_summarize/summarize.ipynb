# %%
import os
from openai import OpenAI

# %%
client = OpenAI(base_url="https://api-obon.conf.in.th/team14/v1", api_key="0000")

# %%
client = OpenAI(
    base_url="https://api.opentyphoon.ai/v1",
    api_key="sk-YjzV9hOLku1hTtp9kbQcFIoXbyXMENF3Ztr7NRIKIrpspKPA",
)

# %%
text = """
อัพเดตความคืบหน้าของสปรินท์
การอภิปรายเกี่ยวกับความท้าทายทางเทคนิค
ข้อเสนอแนะจากการตรวจสอบโค้ด
การจัดลำดับความสำคัญของฟีเจอร์ที่กำลังจะมาถึง
กลยุทธ์การทดสอบ QA

เริ่มกันที่การอัพเดตความคืบหน้าของสปรินท์ ซาร่าห์ ในฐานะนักพัฒนาอาวุโสหลักของเรา คุณช่วยให้ภาพรวมได้ไหม?
นักพัฒนาอาวุโส (ซาร่าห์): ขอบคุณค่ะ PM เราผ่านมาสองสัปดาห์แล้วในสปรินท์หกสัปดาห์ของเรา และเราได้ทำความคืบหน้าที่ดีในฟังก์ชันหลัก แคตตาล็อกสินค้าและฟีเจอร์การค้นหาเสร็จไปแล้วประมาณ 70% เราได้ใช้งานสคีมาฐานข้อมูลพื้นฐานและตั้งค่า API endpoints เบื้องต้นแล้ว อย่างไรก็ตาม เรายังล่าช้าเล็กน้อยในระบบยืนยันตัวตนของผู้ใช้
นักพัฒนาจูเนียร์ (อเล็กซ์): ขอโทษนะครับ ซาร่าห์ คุณช่วยอธิบายได้ไหมครับว่าอะไรทำให้เกิดความล่าช้าในระบบยืนยันตัวตน? ผมกำลังทำงานกับการผสานรวมฝั่งหน้าบ้าน และอยากให้แน่ใจว่าผมไม่ได้ทำให้เกิดการติดขัด
ซาร่าห์: คำถามดีนะคะ อเล็กซ์ เรากำลังถกเถียงกันว่าจะใช้ระบบยืนยันตัวตนของเราเองหรือใช้บริการของบุคคลที่สามอย่าง Auth0 การตัดสินใจนี้ใช้เวลานานกว่าที่คาดไว้ แต่มันสำคัญมากสำหรับความปลอดภัยและความสามารถในการขยายตัว
PM: ขอบคุณสำหรับการอัพเดต เรามาต่อกันที่ความท้าทายทางเทคนิค จอห์น คุณได้กล่าวถึงความกังวลเกี่ยวกับสถาปัตยกรรมแบ็กเอนด์ของเราใช่ไหม?
นักพัฒนาอาวุโส (จอห์น): ใช่ครับ เราต้องตัดสินใจระหว่างสถาปัตยกรรมไมโครเซอร์วิสและแบบโมโนลิธิก เมื่อพิจารณาจากกำหนดเวลาและขนาดทีมของเรา ผมโน้มเอียงไปทางโมโนลิธแบบโมดูลาร์ มันจะง่ายกว่าในการพัฒนาและติดตั้งในตอนแรก และเราสามารถแยกออกเป็นไมโครเซอร์วิสได้ในภายหลังถ้าจำเป็น
ซาร่าห์: ฉันไม่เห็นด้วยค่ะ จอห์น แม้ว่าโมโนลิธอาจจะเร็วกว่าในตอนเริ่มต้น แต่ฉันคิดว่าเราจะได้ประโยชน์จากไมโครเซอร์วิสในระยะยาว โดยเฉพาะสำหรับแพลตฟอร์ม e-commerce ที่ต้องการปรับขนาดส่วนประกอบต่างๆ อย่างอิสระ
PM: นี่เป็นการตัดสินใจที่สำคัญ เรามาฟังความคิดเห็นจากนักพัฒนาอาวุโสอีกคนของเรา ไมค์
นักพัฒนาอาวุโส (ไมค์): ผมเห็นประเด็นทั้งสองฝ่าย ถ้าเราใช้วิธีแบบผสมผสานล่ะครับ? เราสามารถเริ่มต้นด้วยโมโนลิธแบบโมดูลาร์ แต่ออกแบบให้มีขอบเขตที่ชัดเจนซึ่งจะทำให้ง่ายขึ้นในการแยกเป็นไมโครเซอร์วิสในภายหลัง
ผู้เชี่ยวชาญ QA (เอ็มม่า): จากมุมมองการทดสอบ ฉันชอบแนวทางของไมค์ มันจะช่วยให้เราสามารถตั้งค่าการทดสอบการผสานรวมที่ครอบคลุมได้ตั้งแต่เริ่มต้น ในขณะที่ยังคงเปิดโอกาสสำหรับการทดสอบไมโครเซอร์วิสที่ละเอียดขึ้นในอนาคต
PM: ฟังดูเป็นการประนีประนอมที่ดีนะ เรามาใช้ข้อเสนอของไมค์และทบทวนมันอีกครั้งตอนจบสปรินท์นี้ ตอนนี้ เรามาพูดถึงข้อเสนอแนะจากการตรวจสอบโค้ด อเล็กซ์ ผมเชื่อว่าคุณมีคำถามบางอย่าง?
อเล็กซ์: ครับ ผมสังเกตเห็นว่าโค้ดฝั่งหน้าบ้านของเราเป็นการผสมผสานระหว่างคอมโพเนนต์ของ React และ Vue มันกำลังกลายเป็นเรื่องยากที่จะบำรุงรักษา เราควรจะมาตรฐานเป็นเฟรมเวิร์คเดียวไหมครับ?
ซาร่าห์: คุณพูดถูกค่ะ อเล็กซ์ ความไม่สอดคล้องกันนี้เกิดขึ้นเพราะเราเริ่มต้นด้วย React แต่สมาชิกบางคนในทีมถนัด Vue มากกว่า เราควรจะมาตรฐานเป็น React เพราะมันมีประสิทธิภาพที่ดีกว่าสำหรับกรณีการใช้งานของเรา และมีระบบนิเวศที่ใหญ่กว่า
จอห์น: ผมเห็นด้วยกับการทำให้เป็นมาตรฐานเดียว แต่ผมคิดว่าเราควรพิจารณา Vue ด้วย การเรียนรู้มันง่ายกว่า ซึ่งอาจจะเป็นประโยชน์สำหรับนักพัฒนาจูเนียร์ของเรา
PM: เรามาพักเรื่องนี้ไว้ก่อน และกำหนดการประชุมตัดสินใจด้านสถาปัตยกรรมแยกต่างหาก ซาร่าห์ กรุณาเตรียมการเปรียบเทียบระหว่าง React กับ Vue สำหรับความต้องการของโครงการเรา
ตอนนี้ เรามาจัดลำดับความสำคัญของฟีเจอร์ที่กำลังจะมาถึง ลูกค้าของเราต้องการให้เราโฟกัสที่ตะกร้าสินค้าและกระบวนการชำระเงินเป็นลำดับถัดไป มีข้อพิจารณาทางเทคนิคอะไรที่เราควรระวังไหม?
ไมค์: เราต้องแน่ใจว่าฐานข้อมูลของเราสามารถจัดการกับธุรกรรมที่เกิดขึ้นพร้อมกันได้อย่างมีประสิทธิภาพ ผมขอเสนอให้เราใช้การล็อคแบบ optimistic เพื่อจัดการกับความขัดแย้งที่อาจเกิดขึ้นระหว่างการชำระเงิน
เอ็มม่า: จากมุมมองของ QA เราจะต้องทดสอบการผสานรวมเกตเวย์การชำระเงินต่างๆ อย่างละเอียด เราสามารถจัดลำดับความสำคัญในการตั้งค่าสภาพแวดล้อม sandbox สำหรับเรื่องนี้ได้ไหมคะ?
PM: ประเด็นที่ดีมาก เอ็มม่า เรามาทำให้มันเป็นความสำคัญลำดับต้นๆ สำหรับสปรินท์หน้า สุดท้าย เรามาพูดถึงกลยุทธ์การทดสอบ QA เอ็มม่า แผนของคุณเป็นอย่างไรบ้าง?
เอ็มม่า: ฉันวางแผนที่จะใช้การทดสอบแบบผสมผสานทั้งการทดสอบหน่วย การทดสอบการผสานรวม และการทดสอบแบบ end-to-end โดยใช้ Jest และ Cypress เราควรพิจารณาการใช้การทดสอบสัญญา (contract testing) สำหรับ API ของเราด้วย เพื่อให้แน่ใจว่าการผสานรวมระหว่างหน้าบ้านและหลังบ้านราบรื่น
ซาร่าห์: ฟังดูครอบคลุมดีค่ะ เราสามารถรวมการทดสอบประสิทธิภาพด้วยได้ไหม โดยเฉพาะสำหรับฟังก์ชันการค้นหาสินค้า?
เอ็มม่า: ได้เลยค่ะ ฉันจะเพิ่มมันลงในแผนการทดสอบของเรา
"""

# %%
len(text)
# Out:
# 4135

# %%
from langchain.text_splitter import CharacterTextSplitter

text_splitter = CharacterTextSplitter.from_tiktoken_encoder(
    separator=" ",
    chunk_size=700,
    chunk_overlap=100,
    is_separator_regex=False,
    model_name="text-embedding-3-small",
    encoding_name="text-embedding-3-small",
)

doc_list = text_splitter.create_documents([text])

doc_list
# Out:
# [Document(page_content='อัพเดตความคืบหน้าของสปรินท์\nการอภิปรายเกี่ยวกับความท้าทายทางเทคนิค\nข้อเสนอแนะจากการตรวจสอบโค้ด\nการจัดลำดับความสำคัญของฟีเจอร์ที่กำลังจะมาถึง\nกลยุทธ์การทดสอบ QA\n\nเริ่มกันที่การอัพเดตความคืบหน้าของสปรินท์ ซาร่าห์ ในฐานะนักพัฒนาอาวุโสหลักของเรา คุณช่วยให้ภาพรวมได้ไหม?\nนักพัฒนาอาวุโส (ซาร่าห์): ขอบคุณค่ะ PM เราผ่านมาสองสัปดาห์แล้วในสปรินท์หกสัปดาห์ของเรา และเราได้ทำความคืบหน้าที่ดีในฟังก์ชันหลัก แคตตาล็อกสินค้าและฟีเจอร์การค้นหาเสร็จไปแล้วประมาณ 70% เราได้ใช้งานสคีมาฐานข้อมูลพื้นฐานและตั้งค่า API endpoints เบื้องต้นแล้ว อย่างไรก็ตาม เรายังล่าช้าเล็กน้อยในระบบยืนยันตัวตนของผู้ใช้\nนักพัฒนาจูเนียร์ (อเล็กซ์): ขอโทษนะครับ ซาร่าห์ คุณช่วยอธิบายได้ไหมครับว่าอะไรทำให้เกิดความล่าช้าในระบบยืนยันตัวตน? ผมกำลังทำงานกับการผสานรวมฝั่งหน้าบ้าน'),
# ...

# %%
len(doc_list[0].page_content)
# Out:
# 735

# %%
# client.models.list()

# %%
summarize_prompt = "You are an expert in text summarization. Your task is to read and condense the given text so that the main points can be understood quickly and comprehensively.\
            Please summarize the received text appropriately with the same language as article, retaining the meaning and key information. If there are major points, important numbers, or specific information that needs emphasis,\
            please include them. Additionally, use clear and concise language to ensure the summary is highly effective."

bullet_summarize_prompt = """
You are an AI assistant specialized in summarizing text into concise bullet points. Follow these guidelines:

1.Analyze the input text and identify the main ideas and key points.
2.Create a bullet-point summary, with each point capturing a distinct main idea or important detail.
3.Use clear, concise language for each bullet point.
4.Maintain the original meaning and intent of the text.
5.Organize bullet points in a logical order, following the structure of the original text when appropriate.
6.Aim for 3-7 bullet points for most texts, adjusting based on length and complexity.
7.Start each bullet point with a dash (-) for consistency.
8.Avoid redundancy between bullet points.
9.Do not include minor details or examples unless crucial to understanding.
10.If the text contains numerical data or statistics, include the most significant ones in your summary.

Your goal is to provide a clear, concise summary that captures the essence of the original text in an easily digestible format.
"""

list_making_prompt = """ 
Analyze the given article and:

1.Identify the article's language and use it for your response.
2.Extract all mentioned tasks or action items.
3.Categorize each task as "To Do", "Doing", or "Done".
4.Present results in three lists: To Do, Doing, Done.
5.Use clear, concise language matching the article's style.
6.Include category headers even if empty.

I will give you a sample article to practice on.
Input:
    - สปรินท์หกสัปดาห์ผ่านไปสองสัปดาห์, ฟังก์ชันหลักเช่นแคตตาล็อกสินค้าและฟีเจอร์การค้นหามีความคืบหน้า 70%
    - ทีมพัฒนาพิจารณาสถาปัตยกรรมแบ็กเอนด์ระหว่างไมโครเซอร์วิสและโมโนลิธิก, มีแนวโน้มเลือกโมโนลิธิกแบบโมดูลาร์
    - ผู้เชี่ยวชาญ QA เห็นด้วยกับการผสมผสาน: ใช้โมโนลิธิกแบบโมดูลาร์ในตอนแรก, แล้วออกแบบให้มีขอบเขตชัดเจนเพื่อแยกเป็นไมโครเซอร์วิสในภายหลัง
    - ลูกค้าต้องการโฟกัสที่ตะกร้าสินค้าและกระบวนการชำระเงินเป็นลำดับถัดไป
    - สำเร็จการล็อคแบบ optimistic ในฐานข้อมูลเพื่อจัดการธุรกรรมที่เกิดขึ้นพร้อมกันได้
Output:
    To Do:
    1. พิจารณาสถาปัตยกรรมแบ็กเอนด์: ไมโครเซอร์วิส vs โมโนลิธิก
    2. พัฒนาโครงสร้างตะกร้าสินค้าและกระบวนการชำระเงิน

    Doing:
    1. ปรับปรุงแคตตาล็อกสินค้าและฟีเจอร์การค้นหา (70% เสร็จ)
    2. พิจารณาการผสมผสานสถาปัตยกรรมแบ็กเอนด์: โมโนลิธิกแบบโมดูลาร์และไมโครเซอร์วิส

    Done:
    1. จัดการล็อคแบบ optimistic ในฐานข้อมูล

Keep output brief, relevant, and in the same language as the input article. """

# %%
def get_response(task, message):
    completion = client.chat.completions.create(
        model="scb10x/llama-3-typhoon-v1.5x-70b-instruct-awq",
        # model="typhoon-v1.5-instruct",
        messages=[
            {"role": "system", "content": task},
            {"role": "user", "content": message},
        ],
        stop="<|eot_id|>",
        temperature=0,
    )
    return completion.choices[0].message.content


# print(completion.choices[0].message)

# %%
sum_list = []
for i in range(len(doc_list)):
    sum = get_response(summarize_prompt, doc_list[i].page_content)
    sum_list.append(sum)
    print(sum)
    print(i, len(sum))
# Out:
# การอัพเดตความคืบหน้าของสปรินท์เผยว่า ทีมพัฒนาสปรินท์หกสัปดาห์ได้ทำความคืบหน้าที่ดีในฟังก์ชันหลัก แคตตาล็อกสินค้าและฟีเจอร์การค้นหาเสร็จไปแล้วประมาณ 70% และได้ใช้งานสคีมาฐานข้อมูลพื้นฐานและตั้งค่า API endpoints เบื้องต้นแล้ว อย่างไรก็ตาม ทีมยังล่าช้าเล็กน้อยในระบบยืนยันตัวตนของผู้ใช้ ซึ่งอาจเกิดจากความท้าทายทางเทคนิคในการพัฒนาระบบยืนยันตัวตน.
# 0 343
# ทีมกำลังพิจารณาว่าจะใช้ระบบยืนยันตัวตนของตนเองหรือใช้บริการของบุคคลที่สามอย่าง Auth0 ซึ่งการตัดสินใจนี้ใช้เวลานานกว่าที่คาดไว้ แต่มันสำคัญมากสำหรับความปลอดภัยและความสามารถในการขยายตัว นอกจากนี้ยังมีความท้าทายทางเทคนิคในการเลือกสถาปัตยกรรมแบ็กเอนด์ระหว่างไมโครเซอร์วิสและแบบโมโนลิธิก โดยนักพัฒนาอาวุโส (จอห์น) โน้มเอียงไปทางโมโนลิธแบบโมดูลาร์ เนื่องจากมันจะง่ายกว่าในการพัฒนาและติดตั้งในตอนแรก
# 1 392
# ...

# %%
answer = get_response(bullet_summarize_prompt, "\n".join(sum_list))
print(answer)
print(len(answer))
# Out:
# - ทีมพัฒนาสปรินท์หกสัปดาห์ได้ทำความคืบหน้าที่ดีในฟังก์ชันหลัก แคตตาล็อกสินค้าและฟีเจอร์การค้นหาเสร็จไปแล้วประมาณ 70%
# - ทีมยังล่าช้าเล็กน้อยในระบบยืนยันตัวตนของผู้ใช้ และกำลังพิจารณาว่าจะใช้ระบบยืนยันตัวตนของตนเองหรือใช้บริการของบุคคลที่สามอย่าง Auth0
# - ทีมกำลังพิจารณาว่าจะใช้โมโนลิธแบบโมดูลาร์หรือไมโครเซอร์วิสในการพัฒนาแพลตฟอร์ม e-commerce
# - ทีมกำลังพูดคุยเกี่ยวกับการทดสอบและการตรวจสอบโค้ด และตกลงที่จะใช้ข้อเสนอของไมค์ในการตั้งค่าการทดสอบการผสานรวม
# - ทีมกำลังพิจารณาว่าจะใช้ React หรือ Vue เป็นมาตรฐานสำหรับโครงการของพวกเขา
# - ลูกค้าต้องการให้โฟกัสที่ตะกร้าสินค้าและกระบวนการชำระเงินเป็นลำดับถัดไป
# - ทีมกำลังหารือเกี่ยวกับการจัดการความขัดแย้งที่อาจเกิดขึ้นระหว่างการชำระเงิน และพิจารณาการใช้การทดสอบสัญญา (contract testing) สำหรับ API
# - ทีมยังพิจารณารวมการทดสอบประสิทธิภาพด้วย โดยเฉพาะสำหรับฟังก์ชันการค้นหาสินค้า
# 816

# %%
trello = get_response(list_making_prompt, answer)
print(trello)
# Out:
# To Do:
# 1. พัฒนาโครงสร้างตะกร้าสินค้าและกระบวนการชำระเงิน
# 2. ตัดสินใจว่าจะใช้ระบบยืนยันตัวตนของตนเองหรือ Auth0
# 3. ตัดสินใจว่าจะใช้โมโนลิธิกแบบโมดูลาร์หรือไมโครเซอร์วิส
# 4. ตัดสินใจว่าจะใช้ React หรือ Vue เป็นมาตรฐานสำหรับโครงการ
# 5. พัฒนาและปรับปรุงระบบการจัดการความขัดแย้งระหว่างการชำระเงิน
# 6. พัฒนาและปรับปรุงการทดสอบประสิทธิภาพสำหรับฟังก์ชันการค้นหาสินค้า
#
# Doing:
# 1. ปรับปรุงแคตตาล็อกสินค้าและฟีเจอร์การค้นหา (70% เสร็จ)
# 2. พิจารณาการใช้การทดสอบสัญญา (contract testing) สำหรับ API
# 3. พูดคุยเกี่ยวกับการทดสอบและการตรวจสอบโค้ด
#
# Done:
# (No tasks completed)

# %% [markdown]
# ## Kban

# %%
import requests
import json

# %%
url = "https://api.trello.com/1/cards"

headers = {"Accept": "application/json"}
API_KEY = "ca3e3ea2884fd0e3811a4bfc7b6e9cab"
API_TOKEN = (
    "ATTAe088d56c84032b60c76954ff7ce67c11b59ec58be849cc8bf9e552dedd56bdf648CB51C9"
)

# %% [markdown]
# ### test

# %%
# !curl 'https://api.trello.com/1/members/me/boards?key={API_KEY}&token={API_TOKEN}'
# Out:
# [{"id":"66213ced483126ad89ced0b2","nodeId":"ari:cloud:trello::board/workspace/66213cecefa4e77aeb0741fa/66213ced483126ad89ced0b2","name":"Feng Shui","desc":"","descData":null,"closed":false,"dateClosed":null,"idOrganization":"66213cecefa4e77aeb0741fa","idEnterprise":null,"limits":{"attachments":{"perBoard":{"status":"ok","disableAt":36000,"warnAt":28800},"perCard":{"status":"ok","disableAt":1000,"warnAt":800}},"boards":{"totalMembersPerBoard":{"status":"ok","disableAt":1600,"warnAt":1280},"totalAccessRequestsPerBoard":{"status":"ok","disableAt":4000,"warnAt":3200}},"cards":{"openPerBoard":{"status":"ok","disableAt":5000,"warnAt":4000},"openPerList":{"status":"ok","disableAt":5000,"warnAt":4000},"totalPerBoard":{"status":"ok","disableAt":2000000,"warnAt":1600000},"totalPerList":{"status":"ok","disableAt":1000000,"warnAt":800000}},"checklists":{"perBoard":{"status":"ok","disableAt":1800000,"warnAt":1440000},"perCard":{"status":"ok","disableAt":500,"warnAt":400}},"checkItems":{"perCheckl
# ...

# %%
result = """
[{"id":"66213ced483126ad89ced0b2","nodeId":"ari:cloud:trello::board/workspace/66213cecefa4e77aeb0741fa/66213ced483126ad89ced0b2","name":"Feng Shui","desc":"","descData":null,"closed":false,"dateClosed":null,"idOrganization":"66213cecefa4e77aeb0741fa","idEnterprise":null,"limits":{"attachments":{"perBoard":{"status":"ok","disableAt":36000,"warnAt":28800},"perCard":{"status":"ok","disableAt":1000,"warnAt":800}},"boards":{"totalMembersPerBoard":{"status":"ok","disableAt":1600,"warnAt":1280},"totalAccessRequestsPerBoard":{"status":"ok","disableAt":4000,"warnAt":3200}},"cards":{"openPerBoard":{"status":"ok","disableAt":5000,"warnAt":4000},"openPerList":{"status":"ok","disableAt":5000,"warnAt":4000},"totalPerBoard":{"status":"ok","disableAt":2000000,"warnAt":1600000},"totalPerList":{"status":"ok","disableAt":1000000,"warnAt":800000}},"checklists":{"perBoard":{"status":"ok","disableAt":1800000,"warnAt":1440000},"perCard":{"status":"ok","disableAt":500,"warnAt":400}},"checkItems":{"perChecklist":{"status":"ok","disableAt":200,"warnAt":160}},"customFields":{"perBoard":{"status":"ok","disableAt":50,"warnAt":40}},"customFieldOptions":{"perField":{"status":"ok","disableAt":50,"warnAt":40}},"labels":{"perBoard":{"status":"ok","disableAt":1000,"warnAt":800}},"lists":{"openPerBoard":{"status":"ok","disableAt":500,"warnAt":400},"totalPerBoard":{"status":"ok","disableAt":3000,"warnAt":2400}},"stickers":{"perCard":{"status":"ok","disableAt":70,"warnAt":56}},"reactions":{"perAction":{"status":"ok","disableAt":900,"warnAt":720},"uniquePerAction":{"status":"ok","disableAt":17,"warnAt":14}}},"pinned":false,"starred":false,"url":"https://trello.com/b/pXeSN524/feng-shui","prefs":{"permissionLevel":"org","hideVotes":false,"voting":"disabled","comments":"members","invitations":"members","selfJoin":true,"cardCovers":true,"cardCounts":false,"isTemplate":false,"cardAging":"regular","calendarFeedEnabled":false,"hiddenPluginBoardButtons":[],"switcherViews":[{"viewType":"Board","enabled":true},{"viewType":"Table","enabled":true},{"viewType":"Calendar","enabled":false},{"viewType":"Dashboard","enabled":false},{"viewType":"Timeline","enabled":false},{"viewType":"Map","enabled":false}],"background":"pink","backgroundColor":"#CD5A91","backgroundImage":null,"backgroundTile":false,"backgroundBrightness":"dark","sharedSourceUrl":null,"backgroundImageScaled":null,"backgroundBottomColor":"#CD5A91","backgroundTopColor":"#CD5A91","canBePublic":true,"canBeEnterprise":true,"canBeOrg":true,"canBePrivate":true,"canInvite":true},"shortLink":"pXeSN524","subscribed":false,"labelNames":{"green":"Design","yellow":"","orange":"","red":"AI","purple":"","blue":"","sky":"","lime":"","pink":"","black":"","green_dark":"","yellow_dark":"","orange_dark":"","red_dark":"","purple_dark":"","blue_dark":"","sky_dark":"","lime_dark":"","pink_dark":"","black_dark":"","green_light":"","yellow_light":"","orange_light":"","red_light":"","purple_light":"","blue_light":"","sky_light":"","lime_light":"","pink_light":"","black_light":""},"powerUps":[],"dateLastActivity":"2024-04-18T15:49:56.288Z","dateLastView":"2024-06-22T18:54:03.733Z","shortUrl":"https://trello.com/b/pXeSN524","idTags":[],"datePluginDisable":null,"creationMethod":null,"ixUpdate":"96","templateGallery":null,"enterpriseOwned":false,"idBoardSource":null,"premiumFeatures":["additionalBoardBackgrounds","additionalStickers","customBoardBackgrounds","customEmoji","customStickers","plugins"],"idMemberCreator":"662122cdcb4197b5ab86caa7","type":null,"memberships":[{"id":"66213ced483126ad89ced0bc","idMember":"662122cdcb4197b5ab86caa7","memberType":"admin","unconfirmed":false,"deactivated":false},{"id":"66217bf572d0a63040f87d27","idMember":"66217bf472d0a63040f87be0","memberType":"normal","unconfirmed":false,"deactivated":false}]},{"id":"6677458083a9cafc348927d1","nodeId":"ari:cloud:trello::board/workspace/66213cecefa4e77aeb0741fa/6677458083a9cafc348927d1","name":"Meeting 1","desc":"","descData":null,"closed":false,"dateClosed":null,"idOrganization":"66213cecefa4e77aeb0741fa","idEnterprise":null,"limits":{"attachments":{"perBoard":{"status":"ok","disableAt":36000,"warnAt":28800},"perCard":{"status":"ok","disableAt":1000,"warnAt":800}},"boards":{"totalMembersPerBoard":{"status":"ok","disableAt":1600,"warnAt":1280},"totalAccessRequestsPerBoard":{"status":"ok","disableAt":4000,"warnAt":3200}},"cards":{"openPerBoard":{"status":"ok","disableAt":5000,"warnAt":4000},"openPerList":{"status":"ok","disableAt":5000,"warnAt":4000},"totalPerBoard":{"status":"ok","disableAt":2000000,"warnAt":1600000},"totalPerList":{"status":"ok","disableAt":1000000,"warnAt":800000}},"checklists":{"perBoard":{"status":"ok","disableAt":1800000,"warnAt":1440000},"perCard":{"status":"ok","disableAt":500,"warnAt":400}},"checkItems":{"perChecklist":{"status":"ok","disableAt":200,"warnAt":160}},"customFields":{"perBoard":{"status":"ok","disableAt":50,"warnAt":40}},"customFieldOptions":{"perField":{"status":"ok","disableAt":50,"warnAt":40}},"labels":{"perBoard":{"status":"ok","disableAt":1000,"warnAt":800}},"lists":{"openPerBoard":{"status":"ok","disableAt":500,"warnAt":400},"totalPerBoard":{"status":"ok","disableAt":3000,"warnAt":2400}},"stickers":{"perCard":{"status":"ok","disableAt":70,"warnAt":56}},"reactions":{"perAction":{"status":"ok","disableAt":900,"warnAt":720},"uniquePerAction":{"status":"ok","disableAt":17,"warnAt":14}}},"pinned":false,"starred":false,"url":"https://trello.com/b/V4MBo3x3/meeting-1","prefs":{"permissionLevel":"org","hideVotes":false,"voting":"disabled","comments":"members","invitations":"members","selfJoin":true,"cardCovers":true,"cardCounts":false,"isTemplate":false,"cardAging":"regular","calendarFeedEnabled":false,"hiddenPluginBoardButtons":[],"switcherViews":[{"viewType":"Board","enabled":true},{"viewType":"Table","enabled":true},{"viewType":"Calendar","enabled":false},{"viewType":"Dashboard","enabled":false},{"viewType":"Timeline","enabled":false},{"viewType":"Map","enabled":false}],"background":"6677341b6e50a2727a95c1c5","backgroundColor":null,"backgroundImage":"https://trello-backgrounds.s3.amazonaws.com/SharedBackground/original/36c5451b14dba562a2bf106001dae865/photo-1718648872191-99bcfd08bde3","backgroundTile":false,"backgroundBrightness":"dark","sharedSourceUrl":"https://images.unsplash.com/photo-1718648872191-99bcfd08bde3?ixid=M3w3MDY2fDB8MXxjb2xsZWN0aW9ufDF8MzE3MDk5fHx8fHwyfHwxNzE5MDg4MTIyfA&ixlib=rb-4.0.3&w=2560&h=2048&q=90","backgroundImageScaled":[{"width":140,"height":92,"url":"https://trello-backgrounds.s3.amazonaws.com/SharedBackground/140x92/a277bfc5a86127f9cc3308cc4fac3035/photo-1718648872191-99bcfd08bde3.webp"},{"width":256,"height":168,"url":"https://trello-backgrounds.s3.amazonaws.com/SharedBackground/256x168/a277bfc5a86127f9cc3308cc4fac3035/photo-1718648872191-99bcfd08bde3.webp"},{"width":480,"height":316,"url":"https://trello-backgrounds.s3.amazonaws.com/SharedBackground/480x316/a277bfc5a86127f9cc3308cc4fac3035/photo-1718648872191-99bcfd08bde3.webp"},{"width":960,"height":632,"url":"https://trello-backgrounds.s3.amazonaws.com/SharedBackground/960x632/a277bfc5a86127f9cc3308cc4fac3035/photo-1718648872191-99bcfd08bde3.webp"},{"width":1024,"height":674,"url":"https://trello-backgrounds.s3.amazonaws.com/SharedBackground/1024x674/a277bfc5a86127f9cc3308cc4fac3035/photo-1718648872191-99bcfd08bde3.webp"},{"width":1280,"height":842,"url":"https://trello-backgrounds.s3.amazonaws.com/SharedBackground/1280x842/a277bfc5a86127f9cc3308cc4fac3035/photo-1718648872191-99bcfd08bde3.webp"},{"width":1920,"height":1263,"url":"https://trello-backgrounds.s3.amazonaws.com/SharedBackground/1920x1263/a277bfc5a86127f9cc3308cc4fac3035/photo-1718648872191-99bcfd08bde3.webp"},{"width":2048,"height":1347,"url":"https://trello-backgrounds.s3.amazonaws.com/SharedBackground/2048x1347/a277bfc5a86127f9cc3308cc4fac3035/photo-1718648872191-99bcfd08bde3.webp"},{"width":2432,"height":1600,"url":"https://trello-backgrounds.s3.amazonaws.com/SharedBackground/2432x1600/a277bfc5a86127f9cc3308cc4fac3035/photo-1718648872191-99bcfd08bde3.webp"},{"width":2560,"height":1684,"url":"https://trello-backgrounds.s3.amazonaws.com/SharedBackground/2560x1684/a277bfc5a86127f9cc3308cc4fac3035/photo-1718648872191-99bcfd08bde3.webp"}],"backgroundBottomColor":"#191714","backgroundTopColor":"#191d27","canBePublic":true,"canBeEnterprise":true,"canBeOrg":true,"canBePrivate":true,"canInvite":true},"shortLink":"V4MBo3x3","subscribed":false,"labelNames":{"green":"","yellow":"","orange":"","red":"","purple":"","blue":"","sky":"","lime":"","pink":"","black":"","green_dark":"","yellow_dark":"","orange_dark":"","red_dark":"","purple_dark":"","blue_dark":"","sky_dark":"","lime_dark":"","pink_dark":"","black_dark":"","green_light":"","yellow_light":"","orange_light":"","red_light":"","purple_light":"","blue_light":"","sky_light":"","lime_light":"","pink_light":"","black_light":""},"powerUps":[],"dateLastActivity":null,"dateLastView":"2024-06-22T21:43:29.937Z","shortUrl":"https://trello.com/b/V4MBo3x3","idTags":[],"datePluginDisable":null,"creationMethod":null,"ixUpdate":"3","templateGallery":null,"enterpriseOwned":false,"idBoardSource":null,"premiumFeatures":["additionalBoardBackgrounds","additionalStickers","customBoardBackgrounds","customEmoji","customStickers","plugins"],"idMemberCreator":"662122cdcb4197b5ab86caa7","type":null,"memberships":[{"id":"6677458083a9cafc348927e1","idMember":"662122cdcb4197b5ab86caa7","memberType":"admin","unconfirmed":false,"deactivated":false}]},{"id":"662122b5bd53a7b4d10292db","nodeId":"ari:cloud:trello::board/workspace/60cb8557d22d7664e468a173/662122b5bd53a7b4d10292db","name":"kuay","desc":"","descData":null,"closed":false,"dateClosed":null,"idOrganization":"60cb8557d22d7664e468a173","idEnterprise":null,"limits":{"attachments":{"perBoard":{"status":"ok","disableAt":36000,"warnAt":28800},"perCard":{"status":"ok","disableAt":1000,"warnAt":800}},"boards":{"totalMembersPerBoard":{"status":"ok","disableAt":1600,"warnAt":1280},"totalAccessRequestsPerBoard":{"status":"ok","disableAt":4000,"warnAt":3200}},"cards":{"openPerBoard":{"status":"ok","disableAt":5000,"warnAt":4000},"openPerList":{"status":"ok","disableAt":5000,"warnAt":4000},"totalPerBoard":{"status":"ok","disableAt":2000000,"warnAt":1600000},"totalPerList":{"status":"ok","disableAt":1000000,"warnAt":800000}},"checklists":{"perBoard":{"status":"ok","disableAt":1800000,"warnAt":1440000},"perCard":{"status":"ok","disableAt":500,"warnAt":400}},"checkItems":{"perChecklist":{"status":"ok","disableAt":200,"warnAt":160}},"customFields":{"perBoard":{"status":"ok","disableAt":50,"warnAt":40}},"customFieldOptions":{"perField":{"status":"ok","disableAt":50,"warnAt":40}},"labels":{"perBoard":{"status":"ok","disableAt":1000,"warnAt":800}},"lists":{"openPerBoard":{"status":"ok","disableAt":500,"warnAt":400},"totalPerBoard":{"status":"ok","disableAt":3000,"warnAt":2400}},"stickers":{"perCard":{"status":"ok","disableAt":70,"warnAt":56}},"reactions":{"perAction":{"status":"ok","disableAt":900,"warnAt":720},"uniquePerAction":{"status":"ok","disableAt":17,"warnAt":14}}},"pinned":false,"starred":false,"url":"https://trello.com/b/qma7zl26/kuay","prefs":{"permissionLevel":"org","hideVotes":false,"voting":"disabled","comments":"members","invitations":"members","selfJoin":true,"cardCovers":true,"cardCounts":false,"isTemplate":false,"cardAging":"regular","calendarFeedEnabled":false,"hiddenPluginBoardButtons":[],"switcherViews":[{"viewType":"Board","enabled":true},{"viewType":"Table","enabled":true},{"viewType":"Calendar","enabled":false},{"viewType":"Dashboard","enabled":false},{"viewType":"Timeline","enabled":false},{"viewType":"Map","enabled":false}],"background":"gradient-snow","backgroundColor":"#228CD5","backgroundImage":"https://d2k1ftgv7pobq7.cloudfront.net/images/backgrounds/gradients/snow.svg","backgroundTile":false,"backgroundBrightness":"dark","sharedSourceUrl":null,"backgroundImageScaled":null,"backgroundBottomColor":"#37B4C3","backgroundTopColor":"#0C66E4","canBePublic":true,"canBeEnterprise":true,"canBeOrg":true,"canBePrivate":true,"canInvite":true},"shortLink":"qma7zl26","subscribed":false,"labelNames":{"green":"designer","yellow":"Presentation","orange":"","red":"Frontend","purple":"","blue":"","sky":"Backend","lime":"","pink":"","black":"","green_dark":"","yellow_dark":"","orange_dark":"","red_dark":"","purple_dark":"","blue_dark":"","sky_dark":"","lime_dark":"","pink_dark":"","black_dark":"","green_light":"","yellow_light":"","orange_light":"","red_light":"","purple_light":"","blue_light":"","sky_light":"","lime_light":"","pink_light":"","black_light":""},"powerUps":[],"dateLastActivity":"2024-04-20T16:10:22.518Z","dateLastView":"2024-06-22T18:53:46.310Z","shortUrl":"https://trello.com/b/qma7zl26","idTags":[],"datePluginDisable":null,"creationMethod":null,"ixUpdate":"368","templateGallery":null,"enterpriseOwned":false,"idBoardSource":null,"premiumFeatures":["additionalBoardBackgrounds","additionalStickers","customBoardBackgrounds","customEmoji","customStickers","plugins"],"idMemberCreator":"5be64e120624fb59fc646f15","type":null,"memberships":[{"id":"662122b5bd53a7b4d10292e8","idMember":"5be64e120624fb59fc646f15","memberType":"admin","unconfirmed":false,"deactivated":false},{"id":"662122dc1242ac605f538455","idMember":"662122cdcb4197b5ab86caa7","memberType":"normal","unconfirmed":false,"deactivated":false},{"id":"662122efdf76341c22fb3612","idMember":"60c1769641cdca8c9a8ebe68","memberType":"normal","unconfirmed":false,"deactivated":false},{"id":"662122fb12ffc7aeedb765ae","idMember":"65cb41b32b521ffa816525ce","memberType":"normal","unconfirmed":false,"deactivated":false},{"id":"662124d0c476e9c3982ffa21","idMember":"6501bc3107c33d2c0f6973a6","memberType":"normal","unconfirmed":false,"deactivated":false},{"id":"66217bf472d0a63040f87cd1","idMember":"66217bf472d0a63040f87be0","memberType":"normal","unconfirmed":false,"deactivated":false}]}]"""

# %%
# creat pretty json from string
def pretty_json(json_str):
    return json.dumps(json.loads(json_str), indent=2)


print(pretty_json(result))
# Out:
# [
#   {
#     "id": "66213ced483126ad89ced0b2",
#     "nodeId": "ari:cloud:trello::board/workspace/66213cecefa4e77aeb0741fa/66213ced483126ad89ced0b2",
#     "name": "Feng Shui",
#     "desc": "",
#     "descData": null,
#     "closed": false,
#     "dateClosed": null,
#     "idOrganization": "66213cecefa4e77aeb0741fa",
#     "idEnterprise": null,
#     "limits": {
#       "attachments": {
#         "perBoard": {
#           "status": "ok",
#           "disableAt": 36000,
#           "warnAt": 28800
#         },
#         "perCard": {
#           "status": "ok",
#           "disableAt": 1000,
#           "warnAt": 800
#         }
#       },
#       "boards": {
#         "totalMembersPerBoard": {
#           "status": "ok",
#           "disableAt": 1600,
#           "warnAt": 1280
#         },
#         "totalAccessRequestsPerBoard": {
#           "status": "ok",
#           "disableAt": 4000,
#           "warnAt": 3200
#         }
#       },
#       "cards": {
# ...

# %%
id = "6677458083a9cafc348927d1"
url = f"https://api.trello.com/1/boards/{id}/lists"
query = {"key": API_KEY, "token": API_TOKEN}
response = requests.request("GET", url, headers=headers, params=query)

print(
    json.dumps(
        json.loads(response.text), sort_keys=True, indent=4, separators=(",", ": ")
    )
)
# Out:
# [
#     {
#         "closed": false,
#         "color": null,
#         "id": "66774c5dcebc33d490f463fd",
#         "idBoard": "6677458083a9cafc348927d1",
#         "name": "TO-DO",
#         "pos": 65536,
#         "softLimit": null,
#         "subscribed": false
#     },
#     {
#         "closed": false,
#         "color": null,
#         "id": "66774cb80a97a9f6a3a77b1e",
#         "idBoard": "6677458083a9cafc348927d1",
#         "name": "DOING",
#         "pos": 131072,
#         "softLimit": null,
#         "subscribed": false
#     },
#     {
#         "closed": false,
#         "color": null,
#         "id": "66774cbcb80d5f2a51abb4d9",
#         "idBoard": "6677458083a9cafc348927d1",
#         "name": "DONE",
#         "pos": 196608,
#         "softLimit": null,
#         "subscribed": false
#     }
# ]

# %%
url = "https://api.trello.com/1/cards"

data = {
    "name": "New Card Name",
    "desc": "Description of the new card",
}

idList = [
    "66774c5dcebc33d490f463fd",  # TODO
    "66774cb80a97a9f6a3a77b1e",  # DOING
    "66774cbcb80d5f2a51abb4d9",  # DONE
]
idList = idList[0]

query = {"key": API_KEY, "token": API_TOKEN, "idList": idList}

query.update(data)

response = requests.request("POST", url, headers=headers, params=query)

print(
    json.dumps(
        json.loads(response.text), sort_keys=True, indent=4, separators=(",", ": ")
    )
)
# Out:
# {
#     "attachments": [],
#     "badges": {
#         "attachments": 0,
#         "attachmentsByType": {
#             "trello": {
#                 "board": 0,
#                 "card": 0
#             }
#         },
#         "checkItems": 0,
#         "checkItemsChecked": 0,
#         "checkItemsEarliestDue": null,
#         "comments": 0,
#         "description": true,
#         "due": null,
#         "dueComplete": false,
#         "externalSource": null,
#         "fogbugz": "",
#         "lastUpdatedByAi": false,
#         "location": false,
#         "start": null,
#         "subscribed": false,
#         "viewingMemberVoted": false,
#         "votes": 0
#     },
#     "cardRole": null,
#     "checkItemStates": [],
#     "closed": false,
#     "cover": {
#         "brightness": "dark",
#         "color": null,
#         "idAttachment": null,
#         "idPlugin": null,
#         "idUploadedBackground": null,
#         "size": "normal"
#     },
# ...

# %% [markdown]
# ### final

# %%
import re
import requests
import json


def parse_tasks(text):
    sections = re.split(r"\n(?=To Do:|Doing:|Done:)", text.strip())
    tasks = {"To Do": [], "Doing": [], "Done": []}

    for section in sections:
        if section.startswith("To Do:"):
            tasks["To Do"] = re.findall(r"\d+\.\s(.+)", section)
        elif section.startswith("Doing:"):
            tasks["Doing"] = re.findall(r"\d+\.\s(.+)", section)
        elif section.startswith("Done:"):
            tasks["Done"] = re.findall(r"\d+\.\s(.+)", section)

    return tasks


def upload_to_trello(tasks):
    headers = {"Accept": "application/json"}
    API_KEY = "ca3e3ea2884fd0e3811a4bfc7b6e9cab"
    API_TOKEN = (
        "ATTAe088d56c84032b60c76954ff7ce67c11b59ec58be849cc8bf9e552dedd56bdf648CB51C9"
    )
    url = "https://api.trello.com/1/cards"

    idList = {
        "To Do": "66774c5dcebc33d490f463fd",
        "Doing": "66774cb80a97a9f6a3a77b1e",
        "Done": "66774cbcb80d5f2a51abb4d9",
    }

    for status, task_list in tasks.items():
        for task in task_list:
            data = {
                "name": task,
                "desc": f"Task: {task}\nStatus: {status}",
            }
            query = {"key": API_KEY, "token": API_TOKEN, "idList": idList[status]}
            query.update(data)

            response = requests.request("POST", url, headers=headers, params=query)
            print(f"Uploaded task: {task}")
            print(
                json.dumps(
                    json.loads(response.text),
                    sort_keys=True,
                    indent=4,
                    separators=(",", ": "),
                )
            )

# %%
sample_txt = """To Do:
1. ตัดสินใจเกี่ยวกับการใช้งาน Auth0 หรือไม่
2. วิเคราะห์สถาปัตยกรรมแบ็กเอนด์ (ไมโครเซอร์วิส vs โมโนลิธิก) และเลือกโมเดลที่เหมาะสม
3. พัฒนาโครงสร้างตะกร้าสินค้าและกระบวนการชำระเงิน
4. ทดสอบประสิทธิภาพของฟังก์ชันการค้นหาสินค้า

Doing:
1. จัดการกับระบบยืนยันตัวตน
2. พัฒนาฟังก์ชันแคตตาล็อกสินค้าและฟีเจอร์การค้นหา (70% เสร็จสิ้น)

Done:
1. ตัดสินใจใช้โมโนลิธิกแบบโมดูลาร์เป็นสถาปัตยกรรมแบ็กเอนด์
2. ล็อคฐานข้อมูลแบบ optimistic เพื่อจัดการกับธุรกรรมที่เกิดขึ้นพร้อมกัน"""

# %%
print(sample_txt)
# Out:
# To Do:
# 1. ตัดสินใจเกี่ยวกับการใช้งาน Auth0 หรือไม่
# 2. วิเคราะห์สถาปัตยกรรมแบ็กเอนด์ (ไมโครเซอร์วิส vs โมโนลิธิก) และเลือกโมเดลที่เหมาะสม
# 3. พัฒนาโครงสร้างตะกร้าสินค้าและกระบวนการชำระเงิน
# 4. ทดสอบประสิทธิภาพของฟังก์ชันการค้นหาสินค้า
#
# Doing:
# 1. จัดการกับระบบยืนยันตัวตน
# 2. พัฒนาฟังก์ชันแคตตาล็อกสินค้าและฟีเจอร์การค้นหา (70% เสร็จสิ้น)
#
# Done:
# 1. ตัดสินใจใช้โมโนลิธิกแบบโมดูลาร์เป็นสถาปัตยกรรมแบ็กเอนด์
# 2. ล็อคฐานข้อมูลแบบ optimistic เพื่อจัดการกับธุรกรรมที่เกิดขึ้นพร้อมกัน

# %%
# parsed_tasks = parse_tasks(sample_txt)
parsed_tasks = parse_tasks(trello)
parse_tasks
# Out:
# <function __main__.parse_tasks(text)>

# %%
upload_to_trello(parsed_tasks)
# Out:
# Uploaded task: พัฒนาโครงสร้างตะกร้าสินค้าและกระบวนการชำระเงิน
# {
#     "attachments": [],
#     "badges": {
#         "attachments": 0,
#         "attachmentsByType": {
#             "trello": {
#                 "board": 0,
#                 "card": 0
#             }
#         },
#         "checkItems": 0,
#         "checkItemsChecked": 0,
#         "checkItemsEarliestDue": null,
#         "comments": 0,
#         "description": true,
#         "due": null,
#         "dueComplete": false,
#         "externalSource": null,
#         "fogbugz": "",
#         "lastUpdatedByAi": false,
#         "location": false,
#         "start": null,
#         "subscribed": false,
#         "viewingMemberVoted": false,
#         "votes": 0
#     },
#     "cardRole": null,
#     "checkItemStates": [],
#     "closed": false,
#     "cover": {
#         "brightness": "dark",
#         "color": null,
#         "idAttachment": null,
#         "idPlugin": null,
#         "idUploadedBackground": null,
# ...
